# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

#import to filter warnings
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.ticker as ticker
from matplotlib.pyplot import xticks
# %matplotlib inline
sns.set(style="whitegrid")
sns.set(rc={'figure.figsize':(12,8)})
pd.set_option('display.max_rows', 300)
pd.set_option('display.max_columns', 100)
pd.set_option('display.max_colwidth', -1)
import calendar
import datetime as dt

# %%
insta = pd.read_excel("Instagram.xlsx")# Write your code for importing the csv file here
insta.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                        Video_Title  \
# 0  #JugniDhillon #newsongs #ustaad_records\n#punjabimusic #tiktokpunjabi #punjabistars\n#ਅਰਨੋਲੀ_ਵਾਲਾ
# ...

# %%
insta.describe()
# Out:
#        YouTube_AdWords_Placement  YouTube_Video_ID  Category         Views  \
# count  0.0                        0.0               0.0       5000.000000
# mean  NaN                        NaN               NaN        6082.774000
# std   NaN                        NaN               NaN        6859.128583
# min   NaN                        NaN               NaN        1001.000000
# 25%   NaN                        NaN               NaN        2098.750000
# 50%   NaN                        NaN               NaN        3848.000000
# 75%   NaN                        NaN               NaN        7089.000000
# max   NaN                        NaN               NaN        67654.000000
#
#                  V1            V2            V3            V7           V30  \
# count  4439.000000   3428.000000   3136.000000   2381.000000   556.000000
# mean   2904.870016   4130.301634   4856.190370   6481.651407   8759.246403
# ...

# %%
insta.Video_Title
# Out:
# 0       #JugniDhillon #newsongs #ustaad_records\n#punjabimusic #tiktokpunjabi #punjabistars\n#ਅਰਨੋਲੀ_ਵਾਲਾ
# 1       Central Govt Is Not Involved In AP Capital Decision Says Pawan Kalyan\n#CAA #NRC #PawanKalyan #Janasena #JanasenaPressMeet #JSPBJPAlliance #KannaLakshminarayana #PawanKalyan #JanasenaBJPAlliance #BJP #Modi #YCP #CAAProtests #CitizenshipAmendmentAct #CitizenshipActProtests #CitizenshipBill #CMJagan #MangoNews #Telangana #AndhraPradesh #TelanganaNews #andhraNews #hyderabad #Vizag #Visakhapatnam #Vijayawada #Amaravati #Warangal #Kurnool #kakinada
# 2       #chapaakmovie #deepikapadukone #BollywoodActress #JNU #DeepikaInJNU #JNUAttack #JNUSU #AisheGhosh #KanhaiyaKuamr
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell

InteractiveShell.ast_node_interactivity = "all"
insta.Video_Title.str.split(expand=True).stack().value_counts()
# Out:
# .                    10596
# the                  2113
# and                  1700
# to                   1682
# for                  1263
#                      ...
# #haryanalovers       1
# haiyoo               1
# 🥺)                   1
# #truekartikians      1
# @she.be.stephanie    1
# Length: 56463, dtype: int64

# %%
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
from sklearn.feature_extraction import text
stop = text.ENGLISH_STOP_WORDS

# %% [markdown]
# for i in stop :
#     test = insta.Video_Title.replace(to_replace=stop, value="",regex=True)

# %%
test.str.split(expand=True).stack().value_counts()
# Out:
# .          10798
# t          3343
# d          1828
# n          1224
# s          1180
#            ...
# आवाहन..    1
# 😅😂         1
# Pom.       1
# @gurhk     1
# كاربردي    1
# Length: 51355, dtype: int64

# %%
import nltk
nltk.download('stopwords')

from collections import Counter
import pandas as pd
import nltk

top_N = 1000

#df = read_excel("Instagram.xlsx",usecols=['movie_title','plot_keywords'])

stopwords = nltk.corpus.stopwords.words('english')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
stopwords = stopwords + ['#ਾ','#','#','#','#','#','!','onwards','...','...','...','follow',"follow",'🔥','.','.','➡️',
                        '#ਾ','#','#','#','#','#','!','onwards','...','...','...','.','.','.',
    '.','.','.','.','.','..','•','•','•','🔎','?','!!!!!','.','.','.','.','💪','#','..','•','•','•','🔎',
    'अटेंा','ै','🤪🥰','.','@iwmbuzzhindiो','करें।','.','.','.','#','@t_h_e_dictator','@t_h_e_dictator','@t_h_e_dictator',
  '#ff','#','⚡️','⚡️','.', '.',  '.',  '//','every',':sets','powerclean','fs','pushjerk','cluster','#205lbs','.',
  '.','.','.','.','vc','🎬', '————————————————————']

# %%
stopwords = stopwords + [
  

  '#',
  
  '.',
  '.',
  'every',
  ':setstotal',
  'squatsnatchhand)',
  '(',
  '#35kg',
  ')',
  '.',
  '.',
  '.',
  '.',
  'vc',
  '🎬',
  '🎵',
  '/',
   '————————————————————',
   '#',
   '☑️',
  '👉',
  
  '...',
  '🤓',

  '🤓',
  '.✨🔥✨🔥✨🔥✨',
  'copyrightdisclaimer',
  ':',
  '⚠',
  'creditcopyrightnewsmediaphotovideoreservedserved',
  '-',
  '@colorstv',
  ',',
  '@endemolshineind',
  '@vootentireteambiggbosssuitableowner',
  '.',
  '.',
  '***warning***',
  '❌abusecommentsection,',
  'otherwiseblock❌',
  '.',
  '.',
  '?🤔',
  '.',
  'share',

  '.',
  '➖➖➖➖➖➖➖➖➖➖➖➖➖➖',
  '👇',

  '➖➖➖➖➖➖➖➖➖➖➖➖➖➖',
  '.',
  '.',
   '🙏🙏🙏🙏🙏🙏🙏🙏',
   '🖖',
    '🤔👍',
   'dm',
   '*',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '😱',
  'ा',
  'ी',
  '.',
  '.',
  '😉',
   '.',
    '😛',
   '😝',
 '🏻',
  '.',
  '.',
   'े',
  'ा',
    '❤️😍',
   '.',
   '.',
  '.',
  '.',
  '40%',
  '❤',
  '.',
  '.',
  '❤️❤️❤️',
  '.',
  '.',
  '.',
  '.',
  '😍',
  '.',
  '.',
  '.',
   '.',
  '.',
  '.',
  '.',
  '.',
  '.',
  '.']

# %%
RE_stopwords = r'\b(?:{},;:.!.)\b'.format('|'.join(stopwords))

# %%
words = (insta.Video_Title.str.lower().replace([r'\|', RE_stopwords],
                                              [' ',  ''], regex=True).str.cat(sep=' ').split())
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-123-3c8fd38c5880> in <module>
#       1 words = (insta.Video_Title.str.lower().replace([r'\|', RE_stopwords],
# ----> 2                                               [' ',  ''], regex=True).str.cat(sep=' ').split())
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4362             limit=limit,
#    4363             regex=regex,
# -> 4364             method=method,
#    4365         )
#    4366
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6734                         dest_list=value,
#    6735                         inplace=inplace,
# -> 6736                         regex=regex,
#    6737                     )
#    6738
#
# ...

# %%
[words]
# Out:
# [['#jugnidhillon',
#   '#newsongs',
#   '#ustaad_records',
#   '#punjabimusic',
#   '#tiktokpunjabi',
#   '#punjabistars',
#   '#ਲਾ',
#   'central',
#   'govt',
#   'involved',
#   'capital',
#   'decision',
#   'says',
#   'pawan',
#   'kalyan',
#   '#',
#   '#',
#   '#pawankalyan',
#   '#janasena',
#   '#janasenapressmeet',
#   '#jspbjpalliance',
#   '#kannalakshminarayana',
#   '#pawankalyan',
#   '#janasenabjpalliance',
#   '#',
#   '#modi',
#   '#',
#   '#caaprotests',
#   '#citizenshipamendmentact',
#   '#citizenshipactprotests',
#   '#citizenshipbill',
#   '#cmjagan',
#   '#mangonews',
#   '#telangana',
#   '#andhrapradesh',
#   '#telangananews',
#   '#andhranews',
#   '#hyderabad',
#   '#vizag',
#   '#visakhapatnam',
#   '#vijayawada',
#   '#amaravati',
#   '#warangal',
#   '#kurnool',
#   '#kakinada',
#   '#chapaakmovie',
#   '#deepikapadukone',
#   '#bollywoodactress',
#   '#',
#   '#deepikainjnu',
#   '#jnuattack',
#   '#jnusu',
#   '#aisheghosh',
#   '#kanhaiyakuamr',
# ...

# %%
#wordnew=words.replace()
# generate DF out of Counter
rslt = pd.DataFrame(Counter(words).most_common(top_N),
                    columns=['Word', 'Frequency']).set_index('Word')

# %%
print(rslt)
# Out:
#                         Frequency
# Word
# .                       10972
# #                       1680
# •                       660
# -                       462
# #love                   366
# ...                     ...
# #ifslaverywasachoice    19
# #inmyfeelingschallenge  19
# #bestlife               19
# #shiggydance            19
# #wshhfights             19
#
# [1000 rows x 1 columns]

# %%
# plot
rslt.plot.bar(rot=80, figsize=(16,10), width=0.8)
